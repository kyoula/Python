# %%
 #This example uses Python 2.7 and the python-request library.

from requests import Request, Session
from requests.exceptions import ConnectionError, Timeout, TooManyRedirects
import json

url = 'https://pro-api.coinmarketcap.com/v1/cryptocurrency/listings/latest'
parameters = {
  'start':'1',
  'limit':'15',
  'convert':'USD'
}
headers = {
  'Accepts': 'application/json',
  'X-CMC_PRO_API_KEY': 'a773deff-fb97-4b90-8b74-436b870c8d80',
}

session = Session()
session.headers.update(headers)

try:
  response = session.get(url, params=parameters)
  data = json.loads(response.text)
  print(data)
except (ConnectionError, Timeout, TooManyRedirects) as e:
  print(e)
# Out:
# {'status': {'timestamp': '2023-03-22T17:35:17.132Z', 'error_code': 0, 'error_message': None, 'elapsed': 16, 'credit_count': 1, 'notice': None, 'total_count': 9093}, 'data': [{'id': 1, 'name': 'Bitcoin', 'symbol': 'BTC', 'slug': 'bitcoin', 'num_market_pairs': 10101, 'date_added': '2013-04-28T00:00:00.000Z', 'tags': ['mineable', 'pow', 'sha-256', 'store-of-value', 'state-channel', 'coinbase-ventures-portfolio', 'three-arrows-capital-portfolio', 'polychain-capital-portfolio', 'binance-labs-portfolio', 'blockchain-capital-portfolio', 'boostvc-portfolio', 'cms-holdings-portfolio', 'dcg-portfolio', 'dragonfly-capital-portfolio', 'electric-capital-portfolio', 'fabric-ventures-portfolio', 'framework-ventures-portfolio', 'galaxy-digital-portfolio', 'huobi-capital-portfolio', 'alameda-research-portfolio', 'a16z-portfolio', '1confirmation-portfolio', 'winklevoss-capital-portfolio', 'usv-portfolio', 'placeholder-ventures-portfolio', 'pantera-capital-portfolio', 'multicoin-capital-portfolio', 'pa
# ...

# %%
type(data)
# Out:
# dict

# %%
import pandas as pd

pd.set_option('display.max_columns', None)
pd.set_option('display.max_rows',None)

# %%
df=pd.json_normalize(data['data'])

df['timestamp'] = pd.to_datetime('now')
df

# %%
def api_runner():
    global df
    url = 'https://pro-api.coinmarketcap.com/v1/cryptocurrency/listings/latest'
    parameters = {
      'start':'1',
      'limit':'15',
      'convert':'USD'
    }
    headers = {
      'Accepts': 'application/json',
      'X-CMC_PRO_API_KEY': 'a773deff-fb97-4b90-8b74-436b870c8d80',
    }

    session = Session()
    session.headers.update(headers)

    try:
      response = session.get(url, params=parameters)
      data = json.loads(response.text)
      print(data)
    except (ConnectionError, Timeout, TooManyRedirects) as e:
      print(e)

    df = pd.json_normalize(data['data'])
    df['timestamp'] = pd.to_datetime('now')
    df
    
    if not os.path.isfile(r'C:\Users\krist\OneDrive\Documents\python documents for project\API.csv'):
        df.to_csv(r'C:\Users\krist\OneDrive\Documents\python documents for project\API.csv', header='column_names')
    else:
        df.to_csv(r'C:\Users\krist\OneDrive\Documents\python documents for project\API.csv', mode='a', header=False)

# %%
import os
from time import time
from time import sleep

for i in range(333):
    api_runner()
    print('API Runner Completed Successfully')
    sleep(60) #sleep for 1 minute
exit()
# Out:
# C:\Users\krist\anaconda3\lib\site-packages\pandas\core\arrays\datetimes.py:2224: FutureWarning: The parsing of 'now' in pd.to_datetime without `utc=True` is deprecated. In a future version, this will match Timestamp('now') and Timestamp.now()
#   result, tz_parsed = tslib.array_to_datetime(
# ...

# %%
df27 = pd.read_csv(r'C:\Users\krist\OneDrive\Documents\python documents for project\API.csv')
df27

# %%
df
# Out:
#       id         name symbol          slug  num_market_pairs  \
# 0      1      Bitcoin    BTC       bitcoin             10101
# 1   1027     Ethereum    ETH      ethereum              6601
# 2    825       Tether   USDT        tether             49943
# 3   1839          BNB    BNB           bnb              1219
# 4   3408     USD Coin   USDC      usd-coin             11071
# 5     52          XRP    XRP           xrp               907
# 6   2010      Cardano    ADA       cardano               728
# 7     74     Dogecoin   DOGE      dogecoin               664
# 8   3890      Polygon  MATIC       polygon               623
# 9   5426       Solana    SOL        solana               444
# 10  4687  Binance USD   BUSD   binance-usd              6462
# 11  6636     Polkadot    DOT  polkadot-new               484
# 12  5994    Shiba Inu   SHIB     shiba-inu               495
# 13  1958         TRON    TRX          tron               741
# ...

# %%
pd.set_option('display.float_format', lambda x: '%.5f' % x)

# %%
df
# Out:
#       id         name symbol          slug  num_market_pairs  \
# 0      1      Bitcoin    BTC       bitcoin             10101
# 1   1027     Ethereum    ETH      ethereum              6601
# 2    825       Tether   USDT        tether             49943
# 3   1839          BNB    BNB           bnb              1219
# 4   3408     USD Coin   USDC      usd-coin             11071
# 5     52          XRP    XRP           xrp               907
# 6   2010      Cardano    ADA       cardano               729
# 7     74     Dogecoin   DOGE      dogecoin               664
# 8   3890      Polygon  MATIC       polygon               623
# 9   5426       Solana    SOL        solana               444
# 10  4687  Binance USD   BUSD   binance-usd              6462
# 11  6636     Polkadot    DOT  polkadot-new               484
# 12  5994    Shiba Inu   SHIB     shiba-inu               495
# 13  1958         TRON    TRX          tron               741
# ...

# %%
df3 = df.groupby('name', sort=False)[['quote.USD.percent_change_1h','quote.USD.percent_change_24h', 'quote.USD.percent_change_7d', 'quote.USD.percent_change_30d', 'quote.USD.percent_change_60d', 'quote.USD.percent_change_90d' ]].mean()
df3
# Out:
#              quote.USD.percent_change_1h  quote.USD.percent_change_24h  \
# name
# Bitcoin                         -0.01394                       2.03095
# Ethereum                        -0.27191                       0.26547
# Tether                          -0.02456                      -0.01313
# BNB                              0.87464                      -1.81602
# USD Coin                        -0.02875                       0.06883
# XRP                              1.58075                      -1.87680
# Cardano                          1.45020                       7.35460
# Dogecoin                         0.62785                       2.05514
# Polygon                          1.10338                       0.48576
# Solana                           0.82534                       1.39982
# Binance USD                     -0.04252                      -0.06219
# Polkadot                         0.97138                       1.36182
# ...

# %%
df4 = df3.stack()
df4
# Out:
# name
# Bitcoin      quote.USD.percent_change_1h     -0.01394
#              quote.USD.percent_change_24h     2.03095
#              quote.USD.percent_change_7d     18.02678
#              quote.USD.percent_change_30d    15.29428
#              quote.USD.percent_change_60d    23.43317
#              quote.USD.percent_change_90d    72.51373
# Ethereum     quote.USD.percent_change_1h     -0.27191
#              quote.USD.percent_change_24h     0.26547
#              quote.USD.percent_change_7d     10.29294
#              quote.USD.percent_change_30d     5.75161
#              quote.USD.percent_change_60d     8.58483
#              quote.USD.percent_change_90d    51.27119
# Tether       quote.USD.percent_change_1h     -0.02456
#              quote.USD.percent_change_24h    -0.01313
#              quote.USD.percent_change_7d     -0.07057
#              quote.USD.percent_change_30d     0.11703
#              quote.USD.percent_change_60d     0.11424
# ...

# %%
type(df4)
# Out:
# pandas.core.series.Series

# %%
df5 = df4.to_frame(name='values')
df5
# Out:
#                                             values
# name
# Bitcoin     quote.USD.percent_change_1h   -0.01394
#             quote.USD.percent_change_24h   2.03095
#             quote.USD.percent_change_7d   18.02678
#             quote.USD.percent_change_30d  15.29428
#             quote.USD.percent_change_60d  23.43317
#             quote.USD.percent_change_90d  72.51373
# Ethereum    quote.USD.percent_change_1h   -0.27191
#             quote.USD.percent_change_24h   0.26547
#             quote.USD.percent_change_7d   10.29294
#             quote.USD.percent_change_30d   5.75161
#             quote.USD.percent_change_60d   8.58483
#             quote.USD.percent_change_90d  51.27119
# Tether      quote.USD.percent_change_1h   -0.02456
#             quote.USD.percent_change_24h  -0.01313
#             quote.USD.percent_change_7d   -0.07057
#             quote.USD.percent_change_30d   0.11703
#             quote.USD.percent_change_60d   0.11424
# ...

# %%
type(df5)
# Out:
# pandas.core.frame.DataFrame

# %%
df5.count()
# Out:
# values    90
# dtype: int64

# %%
#Updating formatting of name column for visualizations
ndex = pd.Index(range(50))
df6 = df5.reset_index()
df6
# Out:
#            name                       level_1    values
# 0       Bitcoin   quote.USD.percent_change_1h  -0.01394
# 1       Bitcoin  quote.USD.percent_change_24h   2.03095
# 2       Bitcoin   quote.USD.percent_change_7d  18.02678
# 3       Bitcoin  quote.USD.percent_change_30d  15.29428
# 4       Bitcoin  quote.USD.percent_change_60d  23.43317
# 5       Bitcoin  quote.USD.percent_change_90d  72.51373
# 6      Ethereum   quote.USD.percent_change_1h  -0.27191
# 7      Ethereum  quote.USD.percent_change_24h   0.26547
# 8      Ethereum   quote.USD.percent_change_7d  10.29294
# 9      Ethereum  quote.USD.percent_change_30d   5.75161
# 10     Ethereum  quote.USD.percent_change_60d   8.58483
# 11     Ethereum  quote.USD.percent_change_90d  51.27119
# 12       Tether   quote.USD.percent_change_1h  -0.02456
# 13       Tether  quote.USD.percent_change_24h  -0.01313
# 14       Tether   quote.USD.percent_change_7d  -0.07057
# 15       Tether  quote.USD.percent_change_30d   0.11703
# ...

# %%
#Updating column name from level_1 to percent_change
df7 = df6.rename(columns={'level_1': 'percent_change'})
df7
# Out:
#            name                percent_change    values
# 0       Bitcoin   quote.USD.percent_change_1h  -0.01394
# 1       Bitcoin  quote.USD.percent_change_24h   2.03095
# 2       Bitcoin   quote.USD.percent_change_7d  18.02678
# 3       Bitcoin  quote.USD.percent_change_30d  15.29428
# 4       Bitcoin  quote.USD.percent_change_60d  23.43317
# 5       Bitcoin  quote.USD.percent_change_90d  72.51373
# 6      Ethereum   quote.USD.percent_change_1h  -0.27191
# 7      Ethereum  quote.USD.percent_change_24h   0.26547
# 8      Ethereum   quote.USD.percent_change_7d  10.29294
# 9      Ethereum  quote.USD.percent_change_30d   5.75161
# 10     Ethereum  quote.USD.percent_change_60d   8.58483
# 11     Ethereum  quote.USD.percent_change_90d  51.27119
# 12       Tether   quote.USD.percent_change_1h  -0.02456
# 13       Tether  quote.USD.percent_change_24h  -0.01313
# 14       Tether   quote.USD.percent_change_7d  -0.07057
# 15       Tether  quote.USD.percent_change_30d   0.11703
# ...

# %%
df7['percent_change'] = df7['percent_change'].replace(['quote.USD.percent_change_24h','quote.USD.percent_change_7d','quote.USD.percent_change_30d','quote.USD.percent_change_60d','quote.USD.percent_change_90d'],['24h','7d','30d','60d','90d'])
df7
# Out:
#            name percent_change    values
# 0       Bitcoin             1h  -0.01394
# 1       Bitcoin            24h   2.03095
# 2       Bitcoin             7d  18.02678
# 3       Bitcoin            30d  15.29428
# 4       Bitcoin            60d  23.43317
# 5       Bitcoin            90d  72.51373
# 6      Ethereum             1h  -0.27191
# 7      Ethereum            24h   0.26547
# 8      Ethereum             7d  10.29294
# 9      Ethereum            30d   5.75161
# 10     Ethereum            60d   8.58483
# 11     Ethereum            90d  51.27119
# 12       Tether             1h  -0.02456
# 13       Tether            24h  -0.01313
# 14       Tether             7d  -0.07057
# 15       Tether            30d   0.11703
# 16       Tether            60d   0.11424
# 17       Tether            90d   0.13029
# 18          BNB             1h   0.87464
# 19          BNB            24h  -1.81602
# 20          BNB             7d   8.84952
# 21          BNB            30d   5.04556
# ...

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# %%
sns.catplot(x='percent_change', y='values', hue='name', data=df7, kind='point')

# %%
df10 = df[['name', 'quote.USD.price', 'timestamp']]
df10
# Out:
#            name  quote.USD.price                  timestamp
# 0       Bitcoin      28638.81547 2023-03-22 18:10:41.423977
# 1      Ethereum       1796.94937 2023-03-22 18:10:41.423977
# 2        Tether          1.00132 2023-03-22 18:10:41.423977
# 3           BNB        330.53300 2023-03-22 18:10:41.423977
# 4      USD Coin          0.99873 2023-03-22 18:10:41.423977
# 5           XRP          0.44421 2023-03-22 18:10:41.423977
# 6       Cardano          0.37999 2023-03-22 18:10:41.423977
# 7      Dogecoin          0.07677 2023-03-22 18:10:41.423977
# 8       Polygon          1.15017 2023-03-22 18:10:41.423977
# 9        Solana         22.93366 2023-03-22 18:10:41.423977
# 10  Binance USD          0.99936 2023-03-22 18:10:41.423977
# 11     Polkadot          6.31569 2023-03-22 18:10:41.423977
# 12    Shiba Inu          0.00001 2023-03-22 18:10:41.423977
# 13         TRON          0.06714 2023-03-22 18:10:41.423977
# 14     Litecoin         81.82347 2023-03-22 18:10:41.423977

# %%
df10 = df[['name','quote.USD.price','timestamp']]
df10 = df10.query("name == 'Bitcoin'")
df10
# Out:
#       name  quote.USD.price                  timestamp
# 0  Bitcoin      28638.81547 2023-03-22 18:10:41.423977

# %%
sns.set_theme(style="darkgrid")

sns.lineplot(x='timestamp', y='quote.USD.price', data = df10)
# Out:
# <AxesSubplot:xlabel='percent_change', ylabel='values'>
